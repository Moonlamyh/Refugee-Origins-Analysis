# %% [markdown]
# # World Refugee Crisis Remains Unsettled
#
# - Name: Lam Yue Hei, Moon
# - Student ID: 21456550

# %% [markdown]
# Overall, the world is settling the refugee crisis with lower means and median these few years. But the number is getting diverse. There are still rising numbers of refugees in several countries. It includes Syria, where topped the list with over six million refugees only in 2020.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

#set the authentic style of the plots
sns.set_style('whitegrid')

# %%
#load data
df = pd.read_csv(r'C:\Users\Moon Lam\Desktop\Master\AIDM 7330\2nd assignment\Refugee.csv')
#read the first five rows of the data
df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  \
# 0  Refugee population by country or territory of ...  SM.POP.REFG.OR
# 1  Refugee population by country or territory of ...  SM.POP.REFG.OR
# 2  Refugee population by country or territory of ...  SM.POP.REFG.OR
# 3  Refugee population by country or territory of ...  SM.POP.REFG.OR
# 4  Refugee population by country or territory of ...  SM.POP.REFG.OR
#
#        1960      1961      1962      1963      1964      1965  ...       2011  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN  ...        NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN  ...  2771434.0
# ...

# %%
#show all the columns 
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
#find the numbers of rows and columns in the data
df.shape
# Out:
# (266, 65)

# %%
#find the size of the data
df.size
# Out:
# 17290

# %%
#find the len of the dataframe 
print(len(df))
# Out:
# 266

# %% [markdown]
# Q2. the statistical properties of data - categorical: possible values and their frequency

# %%
#using pad method to replace na in 1961-2020. 1960 is not replaced, as it may be replaced by the indicator code instead 
pick = df.iloc[:,5:-1]

# %%
#the social and national probllems change fastly, affecting the number of refugee from a country 
#therefore, only one year (na) is replaced by the previous year (setting the limit to 1)
pick.pad(axis = 1, limit = 1)
# Out:
#          1961      1962      1963      1964      1965      1966      1967  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      5000.0    5000.0   11000.0   35000.0   55000.0   61350.0   60750.0
# 4    150000.0  170000.0  175000.0  200000.0  220000.0  303800.0  356200.0
# ..        ...       ...       ...       ...       ...       ...       ...
# 261       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 262       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 263       NaN       NaN       NaN       NaN       NaN     390.0     450.0
# 264       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 265       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#          1968      1969      1970  ...       2010       2011       2012  \
# ...

# %% [markdown]
# Q2. the statistical properties of data
# o numerical variables: average, maximum, and minimum values

# %%
#find the values of mean, standard deviation, minimum, average, upper and lower quartile, median, and maximum
df.describe().round(2)
# Out:
#            1960       1961      1962       1963        1964        1965  \
# count       1.0       4.00       4.0       6.00       13.00       14.00
# mean   150000.0   76750.00   81750.0   60666.67   133514.62   143234.29
# std         NaN   82858.82   89119.3   80758.07   326869.44   347481.18
# min    150000.0    5000.00    5000.0    5000.00      100.00     3000.00
# 25%    150000.0    5000.00    5000.0    7250.00     5000.00     7500.00
# 50%    150000.0   76000.00   76000.0   12000.00    20300.00    32345.00
# 75%    150000.0  147750.00  152750.0  118750.00    58700.00    74920.00
# max    150000.0  150000.00  170000.0  175000.00  1200000.00  1330000.00
#
#              1966       1967       1968       1969  ...         2011  \
# count       18.00      18.00      23.00      25.00  ...       232.00
# mean    120815.00   56632.78   52554.78   45746.00  ...    606969.62
# std     310871.55   87732.65   87574.32   87888.02  ...   1842191.49
# ...

# %% [markdown]
# Q2. the structure of the dataset

# %%
#finding the structure of the dataset
print(str(df))
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  \
# 0    Refugee population by country or territory of ...  SM.POP.REFG.OR
# 1    Refugee population by country or territory of ...  SM.POP.REFG.OR
# 2    Refugee population by country or territory of ...  SM.POP.REFG.OR
# 3    Refugee population by country or territory of ...  SM.POP.REFG.OR
# ...

# %% [markdown]
# Q2. the data types involved

# %%
#finding the type of the dataframe
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#pick the most recent data to analyze 
df.drop(['Indicator Name', 'Indicator Code','1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'], axis = 1,inplace = True)

# %% [markdown]
# Q2. Frequency of data

# %%
#find the frequency of the dataframe
sns.set(rc={'figure.figsize':(15,8.27)})
#outliers are excluded, as the data is so diverse, or it cannot show the frequency clearly 
frequency = sns.boxplot(data = df, palette = 'rainbow', showfliers = False)
frequency.set_xlabel('Years')
frequency.set_ylabel('Number of Refugee from Origins')
frequency.set_title('Frequency of Refugee Leaving Their Origins')
# Out:
# Text(0.5, 1.0, 'Frequency of Refugee Leaving Their Origins')

# %% [markdown]
# Q2/3. the different data fields that can be useful for your data analysis task

# %%
#find the countries or territories that have less than 20 refugees in 2020
sort2 = df.loc[df['2020']<20]
sort2
# Out:
#                  Country Name Country Code  2014  2015  2016  2017  2018  \
# 6                     Andorra          AND   5.0   5.0   NaN   NaN   NaN
# 37                Switzerland          CHE  16.0  16.0   5.0   5.0   5.0
# 52             Cayman Islands          CYM   6.0   6.0   6.0   6.0   6.0
# 53                     Cyprus          CYP  10.0   NaN   NaN   NaN   7.0
# 58                    Denmark          DNK  11.0  11.0   NaN   NaN   NaN
# 111                   Ireland          IRL   7.0   5.0   NaN   NaN   NaN
# 114                   Iceland          ISL   NaN   NaN   NaN   5.0   5.0
# 141                   Lesotho          LSO  16.0  16.0   5.0   6.0   6.0
# 144                Luxembourg          LUX   NaN   NaN   NaN   NaN   NaN
# 149                    Monaco          MCO   5.0   5.0   5.0   5.0   5.0
# 155          Marshall Islands          MHL   5.0   5.0   5.0   7.0   7.0
# 159                     Malta          MLT   NaN   NaN   NaN   NaN   5.0
# ...

# %%
#get the number of countries that have less than 20 refugees in 2020
print(len(sort2))
# Out:
# 18

# %%
#find the countries or territories that have more than 500,000 refugee in 2020
sort = df.loc[df['2020']>=500000]
sort
# Out:
#                                           Country Name Country Code  \
# 1                          Africa Eastern and Southern          AFE
# 2                                          Afghanistan          AFG
# 3                           Africa Western and Central          AFW
# 7                                           Arab World          ARB
# 34                            Central African Republic          CAF
# 43                                    Congo, Dem. Rep.          COD
# 61         East Asia & Pacific (excluding high income)          EAP
# 62                          Early-demographic dividend          EAR
# 63                                 East Asia & Pacific          EAS
# 69                                             Eritrea          ERI
# 74            Fragile and conflict affected situations          FCS
# 98              Heavily indebted poor countries (HIPC)          HPC
# 102                                          IBRD only          IBD
# ...

# %%
#get the number of countries or territories that have more than 500,000 refugee in 2020
print(len(sort))
# Out:
# 42

# %%
#find the shape of the the countries or territories that have more than 500,000 refugee in 2020
sort.shape
# Out:
# (42, 9)

# %%
#pick only COUNTRY to further analyze 
refugee = df.iloc[[2,34,43,69,160,206,213,216,227]]
refugee
# Out:
#                  Country Name Country Code       2014       2015       2016  \
# 2                 Afghanistan          AFG  2596259.0  2666294.0  2501447.0
# 34   Central African Republic          CAF   412028.0   471093.0   490879.0
# 43           Congo, Dem. Rep.          COD   516765.0   541487.0   537474.0
# 69                    Eritrea          ERI   363081.0   407428.0   457247.0
# 160                   Myanmar          MMR   479006.0   451804.0   490285.0
# 206                     Sudan          SDN   665956.0   627080.0   650391.0
# 213                   Somalia          SOM  1106430.0  1123144.0  1012320.0
# 216               South Sudan          SSD   616206.0   778722.0  1436707.0
# 227      Syrian Arab Republic          SYR  3887490.0  4873236.0  5524511.0
#
#           2017       2018       2019       2020
# 2    2624265.0  2681267.0  2727556.0  2594774.0
# 34    545513.0   590858.0   610152.0   642437.0
# 43    620805.0   720302.0   802974.0   840449.0
# ...

# %%
#make sure there is no na in the dataframe
print(refugee.isna().sum())
# Out:
# Country Name    0
# Country Code    0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# dtype: int64

# %%
#find the values of mean, standard deviation, minimum, average, upper and lower quartile, median, and maximum in the new dataframe
refugee.describe().round(2)
# Out:
#              2014        2015        2016        2017        2018        2019  \
# count        9.00        9.00        9.00        9.00        9.00        9.00
# mean   1182580.11  1326698.67  1455695.67  1762762.44  1806548.33  1800915.22
# std    1230455.21  1506765.56  1665729.27  1884443.63  1974325.47  1961806.37
# min     363081.00   407428.00   457247.00   486209.00   507260.00   504300.00
# 25%     479006.00   471093.00   490879.00   620805.00   720302.00   734780.00
# 50%     616206.00   627080.00   650391.00   986386.00   949637.00   901596.00
# 75%    1106430.00  1123144.00  1436707.00  2439888.00  2285301.00  2234805.00
# max    3887490.00  4873236.00  5524511.00  6310498.00  6654374.00  6615249.00
#
#              2020
# count        9.00
# mean   1798215.22
# std    1970606.71
# min     521949.00
# 25%     787755.00
# 50%     840449.00
# 75%    2189141.00
# max    6689582.00

# %%
#find the shape in the new dataframe
refugee.shape
# Out:
# (9, 9)

# %%
#find the size in the new dataframe
refugee.size
# Out:
# 81

# %%
#sort the new dataframe by descending order
refugee.sort_values(by = '2020', ascending = False, inplace = True)
refugee
# Out:
# <ipython-input-797-72c1f530b89c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refugee.sort_values(by = '2020', ascending = False, inplace = True)
#                  Country Name Country Code       2014       2015       2016  \
# 227      Syrian Arab Republic          SYR  3887490.0  4873236.0  5524511.0
# 2                 Afghanistan          AFG  2596259.0  2666294.0  2501447.0
# 216               South Sudan          SSD   616206.0   778722.0  1436707.0
# 160                   Myanmar          MMR   479006.0   451804.0   490285.0
# 43           Congo, Dem. Rep.          COD   516765.0   541487.0   537474.0
# 213                   Somalia          SOM  1106430.0  1123144.0  1012320.0
# 206                     Sudan          SDN   665956.0   627080.0   650391.0
# ...

# %%
#find the three countries with the most refugees
refugee.head(3)
# Out:
#              Country Name Country Code       2014       2015       2016  \
# 227  Syrian Arab Republic          SYR  3887490.0  4873236.0  5524511.0
# 2             Afghanistan          AFG  2596259.0  2666294.0  2501447.0
# 216           South Sudan          SSD   616206.0   778722.0  1436707.0
#
#           2017       2018       2019       2020
# 227  6310498.0  6654374.0  6615249.0  6689582.0
# 2    2624265.0  2681267.0  2727556.0  2594774.0
# 216  2439888.0  2285301.0  2234805.0  2189141.0

# %%
#multiple bar charts showing the number of refugees that each country have every year
bar = refugee.plot(kind='bar', stacked=False, title='Refugee Population from Countries of Origins with More than 500,000 Refugees')
bar.set_xticklabels(['Syrian Arab Republic','Afghanistan','South Sudan','Myanmar','Congo Dem. Rep.','Somalia','Sudan','Central African Republic','Eritrea'])
# Out:
# [Text(0, 0, 'Syrian Arab Republic'),
#  Text(1, 0, 'Afghanistan'),
#  Text(2, 0, 'South Sudan'),
#  Text(3, 0, 'Myanmar'),
#  Text(4, 0, 'Congo Dem. Rep.'),
#  Text(5, 0, 'Somalia'),
#  Text(6, 0, 'Sudan'),
#  Text(7, 0, 'Central African Republic'),
#  Text(8, 0, 'Eritrea')]

# %%
years = refugee[2:]
name = refugee['Country Name']
syria = refugee.iloc[0,2:]

# %%
#showing the growth of syrian refugee with line chart
years = [2014, 2015, 2016, 2017,2018,2019,2020]
syria = refugee.iloc[0,2:]
plt.plot(years, syria)
plt.xlabel('Years')
plt.ylabel('Population of Refugee from Syria')
plt.title('Refugee Population from Syria from 2014 to 2020')
# Out:
# Text(0.5, 1.0, 'Refugee Population from Syria from 2014 to 2020')

# %%
#showing the growth of eritrean refugee with line chart
years = [2014, 2015, 2016, 2017, 2018, 2019, 2020]
eritrea = refugee.iloc[-1,2:]
plt.plot(years, eritrea)
plt.xlabel('Years')
plt.ylabel('Population of Refugee from Eritrea')
# Out:
# Text(0, 0.5, 'Population of Refugee from Eritrea')

# %%
afg = refugee.iloc[1,2:]
ssd = refugee.iloc[2,2:]
mmr = refugee.iloc[3,2:]
cod = refugee.iloc[4,2:]
som = refugee.iloc[5,2:]
sdn = refugee.iloc[6,2:]
caf = refugee.iloc[7,2:]
eri = refugee.iloc[8,2:]

# %%
#comparing the growth of refugee population in the nine countries throughout 2014 - 2020
x = np.linspace(0, 2, 100) # Return evenly spaced numbers over a specified inte
plt.plot(years, syria, label='Syrian Arab Republic')
plt.plot(years, afg, label='Afghanistan')
plt.plot(years, ssd, label='South Sudan')
plt.plot(years, mmr, label='Myanmar')
plt.plot(years, cod, label='Congo, Dem. Rep.')
plt.plot(years, som, label='Somalia')
plt.plot(years, sdn, label='Sudan')
plt.plot(years, caf, label='Central African Republic')
plt.plot(years, eri, label='Eritrea')

plt.xlabel('Year')
plt.ylabel('Population')
plt.title("Refugee Population by Country of Origin")
plt.legend()
plt.show()

# %%
year2 = ['2014','2015','2016','2017','2018','2019','2020']

# %%
#finding the growing trend of each country seperately 
plt.xticks(fontsize= .02)

plt.subplot(4, 4, 1)
plt.plot(year2, afg)
plt.title("Afghanistan")

plt.subplot(4, 4, 2)
plt.plot(year2, ssd)
plt.title("South Sudan")

plt.subplot(4, 4, 3)
plt.plot(year2, mmr)
plt.title("Myanmar")

plt.subplot(4, 4, 4)
plt.plot(year2, cod)
plt.title("Congo, Dem. Rep.")

plt.subplot(4, 4, 5)
plt.plot(year2, som)
plt.title("Somalia")

plt.subplot(4, 4, 6)
plt.plot(year2, sdn)
plt.title("Sudan")

plt.subplot(4, 4, 7)
plt.plot(year2, caf)
plt.title("Central Africa Republic")

plt.subplot(4, 4, 8)
plt.plot(year2, eri)
plt.title("Eritrea")

plt.subplots_adjust(wspace=.4, hspace=1, top=0.95, bottom=0.1)

plt.show()

# %%
#as somalia is the only country that has decreasing trend, finding its trend individually  
plt.plot(years, som)
plt.xlabel('Years')
plt.ylabel('Population of Refugee from Somalia')
# Out:
# Text(0, 0.5, 'Population of Refugee from Somalia')

# %%
#end
